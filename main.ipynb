# %%
! .venv/bin/python src/qa_prediction/predict_answer.py \
        --model_name "gemma-4-31b-it" \
        -d RoG-webqsp \
        --prompt_path prompts/general_prompt.txt \
        --add_rule \
        --split validation \
        --rule_path results/gen_rule_path/RoG-webqsp/RoG/validation/predictions_3_False.jsonl \
        --cot
# Out:
# Load dataset from finished
# Save results to:  results/KGQA/RoG-webqsp/gemma-4-31b-it/validation/results_gen_rule_path_RoG-webqsp_RoG_validation_predictions_3_False_jsonl_cot
# Prepare pipline for inference...
#   0%|                                                   | 0/246 [00:00<?, ?it/s]Message: Based on the reasoning paths, please answer the given question. Please keep the answer as simple as possible and return all the possible answers as a list. Let's think it step by step.
#
# Reasoning Paths:
# London Heathrow Airport -> location.location.containedby -> United Kingdom
# London Heathrow Airport -> location.location.containedby -> London Heathrow Terminal 2 – The Queen's Terminal
# London Heathrow Airport -> location.location.containedby -> Hillingdon
# London Heathrow Airport -> location.location.containedby -> London
# London Heathrow Airport -> aviation.airport.serves -> 20 Northmoor Road
# London Heathrow Airport -> aviation.airport.serves -> University of Oxford
# London Heathrow Airport -> aviation.airport.serves -> SOAS, University of London
# London Heathrow Airport -> aviation.airport.serves -> Adventures by Disney - England and France Vacation
# London Heathrow Airport -> aviation.airport.serves -> Hilton London Syon Park
# London Heathrow Airport -> location.location.nearby_airports -> Conrad London St. James
# London Heathrow Airport -> location.location.nearby_airports -> Yotel London Heathrow
# London Heathrow Airport -> location.location.nearby_airports -> Slough
# London Heathrow Airport -> location.location.nearby_airports -> London Borough of Hillingdon
#
# Question:
# what county is heathrow airport in?
# Number of token: 430
# 500 INTERNAL. {'error': {'code': 500, 'message': 'Internal error encountered.', 'status': 'INTERNAL'}}
#   1%|▌                                          | 3/246 [00:09<13:15,  3.28s/it]
# Traceback (most recent call last):
#   File "/home/noah/reasoning-on-graphs/src/qa_prediction/../llms/language_models/gemini.py", line 108, in generate_sentence
#     response = client.models.generate_content(
#   File "/home/noah/reasoning-on-graphs/.venv/lib/python3.10/site-packages/google/genai/models.py", line 6454, in generate_content
#     response = self._generate_content(
#   File "/home/noah/reasoning-on-graphs/.venv/lib/python3.10/site-packages/google/genai/models.py", line 4890, in _generate_content
#     response = self._api_client.request(
#   File "/home/noah/reasoning-on-graphs/.venv/lib/python3.10/site-packages/google/genai/_api_client.py", line 1611, in request
#     response = self._request(http_request, http_options, stream=False)
#   File "/home/noah/reasoning-on-graphs/.venv/lib/python3.10/site-packages/google/genai/_api_client.py", line 1404, in _request
#     return self._retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#   File "/home/noah/reasoning-on-graphs/.venv/lib/python3.10/site-packages/tenacity/__init__.py", line 470, in __call__
#     do = self.iter(retry_state=retry_state)
#   File "/home/noah/reasoning-on-graphs/.venv/lib/python3.10/site-packages/tenacity/__init__.py", line 371, in iter
#     result = action(retry_state)
#   File "/home/noah/reasoning-on-graphs/.venv/lib/python3.10/site-packages/tenacity/__init__.py", line 413, in exc_check
#     raise retry_exc.reraise()
#   File "/home/noah/reasoning-on-graphs/.venv/lib/python3.10/site-packages/tenacity/__init__.py", line 184, in reraise
#     raise self.last_attempt.result()
#   File "/home/noah/.local/share/uv/python/cpython-3.10.20-linux-x86_64-gnu/lib/python3.10/concurrent/futures/_base.py", line 451, in result
#     return self.__get_result()
#   File "/home/noah/.local/share/uv/python/cpython-3.10.20-linux-x86_64-gnu/lib/python3.10/concurrent/futures/_base.py", line 403, in __get_result
#     raise self._exception
#   File "/home/noah/reasoning-on-graphs/.venv/lib/python3.10/site-packages/tenacity/__init__.py", line 473, in __call__
#     result = fn(*args, **kwargs)
#   File "/home/noah/reasoning-on-graphs/.venv/lib/python3.10/site-packages/google/genai/_api_client.py", line 1381, in _request_once
#     errors.APIError.raise_for_response(response)
#   File "/home/noah/reasoning-on-graphs/.venv/lib/python3.10/site-packages/google/genai/errors.py", line 155, in raise_for_response
#     cls.raise_error(response.status_code, response_json, response)
#   File "/home/noah/reasoning-on-graphs/.venv/lib/python3.10/site-packages/google/genai/errors.py", line 186, in raise_error
#     raise ServerError(status_code, response_json, response)
# google.genai.errors.ServerError: 500 INTERNAL. {'error': {'code': 500, 'message': 'Internal error encountered.', 'status': 'INTERNAL'}}
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/noah/reasoning-on-graphs/src/qa_prediction/predict_answer.py", line 231, in <module>
#     main(args, LLM)
#   File "/home/noah/reasoning-on-graphs/src/qa_prediction/predict_answer.py", line 174, in main
#     res = prediction(data, processed_list, input_builder, model)
#   File "/home/noah/reasoning-on-graphs/src/qa_prediction/predict_answer.py", line 80, in prediction
#     prediction = model.generate_sentence(input)
#   File "/home/noah/reasoning-on-graphs/src/qa_prediction/../llms/language_models/gemini.py", line 121, in generate_sentence
#     time.sleep(30)
# KeyboardInterrupt
# ^C

# %%
! .venv/bin/python src/qa_prediction/predict_answer.py \
        --model_name "gemini-3.1-flash-lite" \
        -d RoG-webqsp \
        --prompt_path prompts/general_prompt.txt \
        --add_rule \
        --split validation \
        --rule_path results/gen_rule_path/RoG-webqsp/RoG/validation/predictions_3_False.jsonl \
        --cot
